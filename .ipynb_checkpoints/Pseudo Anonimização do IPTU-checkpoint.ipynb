# %% [markdown]
# # Pseudo Anonimização dos dados de Contribuinte do IPTU

# %%
hash_anonimizada = hashlib.md5('DADO PARA SER ANONIMIZADO'.encode('iso-8859-9')).hexdigest()

# %%
print(hash_anonimizada)
# Out:
# 512141181c5031e9bcfcf7266c42a4b5

# %%
hash_procurada = hashlib.md5('DADO ANONIMO PARA SER PROCURADO'.encode('iso-8859-9')).hexdigest()

# %%
if hash_anonimizada == hash_procurada:
    print('Dados são iguais')
else:
    print('Os dados não conferem')
# Out:
# Os dados não conferem

# %% [markdown]
# ## Carregando as bibliotecas

# %%
import pandas as pd

# %%
import hashlib

# %% [markdown]
# ## Abrindo a base de IPTU

# %%
exercicio = '2019'

# %%
df_iptu = pd.read_csv(f'download/IPTU_{exercicio}.zip',\
          compression='zip',\
          encoding='iso-8859-9',\
          sep=';',\
          decimal=',',\
          error_bad_lines=False)

# %% [markdown]
# ## Redefenindo colunas

# %%
colunas = list(df_iptu.columns)

# %%
colunas.remove('CPF/CNPJ DO CONTRIBUINTE 1')

# %%
colunas.remove('NOME DO CONTRIBUINTE 1')

# %%
colunas.remove('CPF/CNPJ DO CONTRIBUINTE 2')

# %%
colunas.remove('NOME DO CONTRIBUINTE 2')

# %%
colunas.insert(5,'HASH CONTRIBUINTE 1')

# %%
colunas.insert(7,'HASH CONTRIBUINTE 2')

# %%
colunas
# Out:
# ['NUMERO DO CONTRIBUINTE',
#  'ANO DO EXERCICIO',
#  'NUMERO DA NL',
#  'DATA DO CADASTRAMENTO',
#  'TIPO DE CONTRIBUINTE 1',
#  'HASH CONTRIBUINTE 1',
#  'TIPO DE CONTRIBUINTE 2',
#  'HASH CONTRIBUINTE 2',
#  'NUMERO DO CONDOMINIO',
#  'CODLOG DO IMOVEL',
#  'NOME DE LOGRADOURO DO IMOVEL',
#  'NUMERO DO IMOVEL',
#  'COMPLEMENTO DO IMOVEL',
#  'BAIRRO DO IMOVEL',
#  'REFERENCIA DO IMOVEL',
#  'CEP DO IMOVEL',
#  'QUANTIDADE DE ESQUINAS/FRENTES',
#  'FRACAO IDEAL',
#  'AREA DO TERRENO',
#  'AREA CONSTRUIDA',
#  'AREA OCUPADA',
#  'VALOR DO M2 DO TERRENO',
#  'VALOR DO M2 DE CONSTRUCAO',
#  'ANO DA CONSTRUCAO CORRIGIDO',
#  'QUANTIDADE DE PAVIMENTOS',
#  'TESTADA PARA CALCULO',
#  'TIPO DE USO DO IMOVEL',
#  'TIPO DE PADRAO DA CONSTRUCAO',
#  'TIPO DE TERRENO',
#  'FATOR DE OBSOLESCENCIA',
#  'ANO DE INICIO DA VIDA DO CONTRIBUINTE',
#  'MES DE INICIO DA VIDA DO CONTRIBUINTE',
#  'FASE DO CONTRIBUINTE',
#  'HASH CONTRIBUINTE 2']

# %% [markdown]
# ## Pseudo Anonimizando
#
# É gerado uma [hash MD5 de 128 bits](https://pt.wikipedia.org/wiki/MD5) para cada coluna de CPF/CNPJ concatenada com o nome

# %%
c1 = df_iptu.loc[df_iptu['NOME DO CONTRIBUINTE 1'].notna()]

# %%
df_iptu['HASH CONTRIBUINTE 1'] = \
(c2['CPF/CNPJ DO CONTRIBUINTE 1'] + c2['NOME DO CONTRIBUINTE 1']).apply(
    lambda x: hashlib.md5(x.encode('iso-8859-9')).hexdigest()
)

# %%
c2 = df_iptu.loc[df_iptu['NOME DO CONTRIBUINTE 2'].notna()]

# %%
df_iptu['HASH CONTRIBUINTE 2'] = \
(c2['CPF/CNPJ DO CONTRIBUINTE 2'] + c2['NOME DO CONTRIBUINTE 2']).apply(
    lambda x: hashlib.md5(x.encode('iso-8859-9')).hexdigest()
)

# %% [markdown]
# ## Salvando os dados processados Pseudo Anonimizados

# %%
df_iptu[colunas]
# Out:
#         NUMERO DO CONTRIBUINTE  ANO DO EXERCICIO  NUMERO DA NL  \
# 0                 0010030001-4              2019             1
# 1                 0010030002-2              2019             1
# 2                 0010030003-0              2019             1
# 3                 0010030004-9              2019             1
# 4                 0010030005-7              2019             1
# ...                        ...               ...           ...
# 3447107           3101180238-1              2019             1
# 3447108           3101180239-1              2019             1
# 3447109           3101180240-3              2019             1
# 3447110           3101190001-4              2019             1
# 3447111           3101200001-7              2019             1
#
#         DATA DO CADASTRAMENTO  TIPO DE CONTRIBUINTE 1 TIPO DE CONTRIBUINTE 2  \
# 0                    12/01/19     PESSOA FISICA (CPF)                    NaN
# 1                    12/01/19     PESSOA FISICA (CPF)                    NaN
# 2                    12/01/19     PESSOA FISICA (CPF)                    NaN
# 3                    12/01/19     PESSOA FISICA (CPF)                    NaN
# 4                    12/01/19     PESSOA FISICA (CPF)                    NaN
# ...                       ...                     ...                    ...
# 3447107              12/01/19     PESSOA FISICA (CPF)                    NaN
# 3447108              12/01/19     PESSOA FISICA (CPF)                    NaN
# 3447109              12/01/19     PESSOA FISICA (CPF)    PESSOA FISICA (CPF)
# 3447110              12/01/19  PESSOA JURIDICA (CNPJ)                    NaN
# 3447111              12/01/19  PESSOA JURIDICA (CNPJ)                    NaN
#
#         NUMERO DO CONDOMINIO CODLOG DO IMOVEL  \
# 0                       00-0          03812-1
# 1                       00-0          03812-1
# 2                       00-0          03812-1
# 3                       00-0          03812-1
# 4                       00-0          03812-1
# ...                      ...              ...
# 3447107                 01-9          02235-7
# 3447108                 01-9          02235-7
# 3447109                 01-9          02235-7
# 3447110                 00-0          19137-0
# 3447111                 00-0          01041-3
#
#              NOME DE LOGRADOURO DO IMOVEL  NUMERO DO IMOVEL  ...  \
# 0                             R S CAETANO              13.0  ...
# 1                             R S CAETANO              19.0  ...
# 2                             R S CAETANO              27.0  ...
# 3                             R S CAETANO              33.0  ...
# 4                             R S CAETANO              39.0  ...
# ...                                   ...               ...  ...
# 3447107  AV ENG ARMANDO DE ARRUDA PEREIRA            1827.0  ...
# 3447108  AV ENG ARMANDO DE ARRUDA PEREIRA            1827.0  ...
# 3447109  AV ENG ARMANDO DE ARRUDA PEREIRA            1827.0  ...
# 3447110                       R  COTIPORA               NaN  ...
# 3447111                        R  AMBORES               NaN  ...
#
#         QUANTIDADE DE PAVIMENTOS TESTADA PARA CALCULO  \
# 0                              1                13.00
# 1                              1                 6.00
# 2                              2                 7.85
# 3                              1                 6.05
# 4                              1                 6.70
# ...                          ...                  ...
# 3447107                        5                 0.00
# 3447108                        5                 0.00
# 3447109                        5                 0.00
# 3447110                        0                 0.00
# 3447111                        0               500.00
#
#              TIPO DE USO DO IMOVEL     TIPO DE PADRAO DA CONSTRUCAO  \
# 0                             Loja  Comercial horizontal - padrão B
# 1                             Loja  Comercial horizontal - padrão B
# 2                             Loja  Comercial horizontal - padrão B
# 3                             Loja  Comercial horizontal - padrão B
# 4                             Loja  Comercial horizontal - padrão B
# ...                            ...                              ...
# 3447107  Apartamento em condomínio  Residencial vertical - padrão B
# 3447108  Apartamento em condomínio  Residencial vertical - padrão B
# 3447109  Apartamento em condomínio  Residencial vertical - padrão B
# 3447110                    Terreno                          TERRENO
# 3447111                    Terreno                          TERRENO
#
#          TIPO DE TERRENO  FATOR DE OBSOLESCENCIA  \
# 0             De esquina                    0.20
# 1                 Normal                    0.20
# 2                 Normal                    0.32
# 3                 Normal                    0.20
# 4                 Normal                    0.20
# ...                  ...                     ...
# 3447107       De esquina                    0.20
# 3447108       De esquina                    0.20
# 3447109       De esquina                    0.20
# 3447110       De esquina                    0.00
# 3447111           Normal                    0.00
#
#          ANO DE INICIO DA VIDA DO CONTRIBUINTE  \
# 0                                         1963
# 1                                         1963
# 2                                         1963
# 3                                         1963
# 4                                         1963
# ...                                        ...
# 3447107                                   1985
# 3447108                                   1985
# 3447109                                   1985
# 3447110                                   1988
# 3447111                                   1988
#
#          MES DE INICIO DA VIDA DO CONTRIBUINTE  FASE DO CONTRIBUINTE  \
# 0                                            1                     0
# 1                                            1                     0
# 2                                            1                     0
# 3                                            1                     0
# 4                                            1                     0
# ...                                        ...                   ...
# 3447107                                      1                     0
# 3447108                                      1                     0
# 3447109                                      1                     0
# 3447110                                      1                     0
# 3447111                                      1                     0
#
#                       HASH CONTRIBUINTE 2
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 3447107                               NaN
# 3447108                               NaN
# 3447109  5b0654eca47be77965c8c9a2d5a9e77c
# 3447110                               NaN
# 3447111                               NaN
#
# [3447112 rows x 32 columns]
